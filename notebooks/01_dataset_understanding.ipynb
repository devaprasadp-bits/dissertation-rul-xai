# %% [markdown]
# # 01 – Dataset Understanding
#
# **Goal:** Load the NASA CMAPSS turbofan engine dataset, explore its structure, and gain intuition about the sensor signals and degradation patterns.
#
# **Dataset:** [CMAPSS – Turbofan Engine Degradation Simulation](https://www.nasa.gov/intelligent-systems-division/discovery-and-systems-health/pcoe/pcoe-data-set-repository/)
#
# ---

# %% [markdown]
# ## 1. Imports & Setup

# %% [markdown]
# ## 2. Column Definitions
#
# CMAPSS files are space-delimited with no header. We assign column names manually.

# %% [markdown]
# ## 3. Load Data
#
# Place the CMAPSS files (`train_FD001.txt`, `test_FD001.txt`, `RUL_FD001.txt`) in `data/raw/` before running.

# %% [markdown]
# ## 4. Basic Statistics

# %% [markdown]
# ## 5. Engine Lifetime Distribution

# %% [markdown]
# ## 6. Sensor Signal Visualisation (Sample Engine)

# %% [markdown]
# ## 7. Sensor Variance Analysis
#
# Identify low-variance sensors that can be dropped.

# %% [markdown]
# ## 8. Correlation Heatmap

# %% [markdown]
# ## 9. Summary
#
# - Total training engines: `train_df['unit_id'].nunique()`
# - Key observations:
#   - Several sensors show near-zero variance → candidates for removal.
#   - Clear degradation trends visible in sensors such as sensor_2, sensor_3, sensor_4.
#   - Engine lifetimes range approximately 120–360 cycles for FD001.
#
# **Next step:** `02_rul_label_preparation.ipynb`
