# %% [markdown]
# # 02 – RUL Label Preparation
#
# **Goal:** Compute piece-wise linear (PWL) RUL labels for the training set, apply sensor preprocessing (normalisation, dropping low-variance sensors), and create a sliding-window dataset saved to `data/processed/`.
#
# ---

# %% [markdown]
# ## 1. Imports & Config

# %% [markdown]
# ## 2. Load Raw Data

# %% [markdown]
# ## 3. Compute Piece-Wise Linear RUL Labels
#
# RUL is capped at `MAX_RUL`. In early life the engine is assumed healthy, so RUL is clamped to `MAX_RUL` until degradation is observable.

# %% [markdown]
# ## 4. Drop Low-Variance Sensors & Operational Settings

# %% [markdown]
# ## 5. Min-Max Normalisation

# %% [markdown]
# ## 6. Sliding Window Construction

# %% [markdown]
# ## 7. Save Processed Data

# %% [markdown]
# ## 8. Summary
#
# - RUL labels computed with PWL capping at `MAX_RUL=125`.
# - Low-variance sensors removed; remaining features normalised (MinMax).
# - Sliding windows of `WINDOW=30` cycles created.
# - Processed `.npy` files and scaler saved to `data/processed/`.
#
# **Next step:** `03_baseline_model.ipynb`
