# %% [markdown]
# # 03 – Baseline Model
#
# **Goal:** Train a baseline RUL prediction model and evaluate its performance.
#
# ---

# %% [markdown]
# ## 1. Imports & Config

# %% [markdown]
# ## 2. Load Processed Data

# %% [markdown]
# ## 3. Model Definition

# %% [markdown]
# ## 4. Training Loop

# %% [markdown]
# ## 5. Evaluation (RMSE, MAE, Score)

# %% [markdown]
# ## 6. Predictions vs Ground Truth

# %% [markdown]
# ## 7. Save Model & Results
